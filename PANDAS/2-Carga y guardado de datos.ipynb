# %% [markdown]
# Id cargando todos los ficheros en vuestro jupyter.

# %%
import pandas as pd
import os

# %%
archivo_csv = pd.read_csv("DATOS/quejas.csv", encoding = "latin-1", sep = ";")
archivo_csv
# Out:
#             tipo                   estado canal_entrada        fecha_entrada  \
# 0          Queja  Recepcionada por Unidad      INTERNET  2022-01-28 00:00:00
# 1          Queja  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
# 2          Queja  Recepcionada por Unidad      INTERNET  2022-03-23 00:00:00
# 3          Queja  Recepcionada por Unidad      INTERNET  2022-01-24 00:00:00
# 4          Queja  Recepcionada por Unidad      INTERNET  2022-03-29 00:00:00
# ...          ...                      ...           ...                  ...
# 4494  Sugerencia                Cancelada      INTERNET  2022-01-02 00:00:00
# 4495  Sugerencia       Rechazada por SGAC      INTERNET  2022-03-08 00:00:00
# 4496       Queja       Rechazada por SGAC      INTERNET  2022-01-24 00:00:00
# 4497       Queja       Rechazada por SGAC      INTERNET  2022-01-21 00:00:00
# 4498       Queja       Rechazada por SGAC      INTERNET  2022-01-21 00:00:00
#
# ...

# %%
archivo_json = pd.read_json("DATOS/quejas.json")
archivo_json
# Out:
#                                                    data
# 0     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 1     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 2     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 3     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 4     {'unidad_descripcion': 'D.G. de Descarbonizaci...
# ...                                                 ...
# 4442  {'unidad_descripcion': '', 'tipo': 'Sugerencia...
# 4443  {'unidad_descripcion': '', 'tipo': 'Sugerencia...
# 4444  {'unidad_descripcion': '', 'tipo': 'Queja', 'e...
# 4445  {'unidad_descripcion': '', 'tipo': 'Queja', 'e...
# 4446  {'unidad_descripcion': '', 'tipo': 'Queja', 'e...
#
# [4447 rows x 1 columns]

# %%
archivo_xlsx = pd.read_excel("DATOS/quejas2.xlsx")
archivo_xlsx
# Out:
#           DESCRIPCION_TEMA                                DESCRIPCION_SUBTEMA
# 0    ATENCIÓN AL CIUDADANO                         ADMINISTRACIÓN ELECTRÓNICA
# 1    ATENCIÓN AL CIUDADANO                                    FUNCIÓN PÚBLICA
# 2    ATENCIÓN AL CIUDADANO  OFICINAS DE ATENCIÓN AL CIUDADANO DE LA COMUNI...
# 3    ATENCIÓN AL CIUDADANO     OFICINAS DE REGISTRO DE LA COMUNIDAD DE MADRID
# 4    ATENCIÓN AL CIUDADANO                                              OTROS
# ..                     ...                                                ...
# 179               VIVIENDA                                       PLAN ALQUILA
# 180               VIVIENDA                             PLAN DE VIVIENDA JOVEN
# 181               VIVIENDA                                 PORTAL DE VIVIENDA
# 182               VIVIENDA                   PUNTOS DE INFORMACIÓN Y REGISTRO
# 183               VIVIENDA                                VIVIENDAS DEL IVIMA
#
# [184 rows x 2 columns]

# %%
archivo_pickle = pd.read_pickle("DATOS/algas.pickle")
archivo_pickle
# Out:
#       Unnamed: 0       lon      lat    locality  year  month    kingdom  \
# 0             22  -70.7167  43.0750  New Castle  1900    5.0  Chromista
# 1             23  -70.7167  43.0750  New Castle  1900    5.0  Chromista
# 2             24  -70.7167  43.0750  New Castle  1900    5.0    Plantae
# 3             33 -158.1170  21.5833     Haleiwa  1900    6.0    Plantae
# 4             35   -7.0000  62.1800     Hvalvík  1900    6.0  Chromista
# ...          ...       ...      ...         ...   ...    ...        ...
# 6691       27748 -125.1548  48.8266    Bamfield  2020    2.0  Chromista
# 6692       27752 -125.1549  48.8264    Bamfield  2020    2.0  Chromista
# 6693       27759 -125.1550  48.8264    Bamfield  2020    2.0    Plantae
# 6694       27776 -125.1549  48.8264    Bamfield  2020    2.0  Chromista
# 6695       27781 -125.1542  48.8269    Bamfield  2020    2.0    Plantae
#
#                 class        family      genus            species  \
# ...

# %%
archivo_pepinillo = pd.read_clipboard(sep = "\t")
archivo_pepinillo
# Out:
#                                                       Macronutrientes
# Hidratos de carbono    Grasas monoinsaturadas  Grasas poliinsaturadas
# 4,50 g                 0 g                                        0 g
# Proteína (Ver ranking) Proteína Animal               Proteína vegetal
# 1,70 g                 0 g                                     1,70 g
# Fibra (Ver ranking)    Agua                                   Omega 3
# 1,20 g                 92,60 g                                    0 g
# Omega 6
# 0,0590 g               NaN                                        NaN

# %%
archivo_pepinillo.to_json("DATOS/pepinillos.json")
archivo_pepinillo.to_excel("DATOS/pepinillos.xlsx")
archivo_pepinillo.to_pickle("DATOS/pepinillos.pickle")
archivo_pepinillo.to_csv("DATOS/pepinillos.csv")

# %%
archivo_pepinillo_2 = pd.read_clipboard(sep = "\t")
archivo_pepinillo_2
# Out:
#                         Celiacos  X  Unnamed: 2
# 0   Alérgicos a los frutos secos  X         NaN
# 1           Alérgicos al marisco  X         NaN
# 2           Alérgicos al pescado  X         NaN
# 3             Alérgicos al huevo  X         NaN
# 4      Intolerantes a la lactosa  X         NaN
# 5        Diabéticos con insulina  X         NaN
# 6        Diabéticos sin insulina  X         NaN
# 7                    Embarazadas  X         NaN
# 8                          Niños  X         NaN
# 9                   Vegetarianos  X         NaN
# 10                       Veganos  X         NaN
# 11                        Judíos  X         NaN
# 12                    Musulmanes  X         NaN
# 13                    Hinduístas  X         NaN

# %%
archivo_panda = pd.read_clipboard(sep = ":")
archivo_panda
# Out:
#                     Body length                     120–180cm (47–71")
# 0               Shoulder height                       54–81cm (21–32")
# 1                    Hip height                       52–77cm (20–30")
# 2                   Chest girth                      70–106cm (28–42")
# 3               Hind leg length                         12–20cm (5–8")
# 4                   Tail length                         10–20cm (4–8")
# 5       Wild giant panda weight                 60–110 kg (132–243 lb)
# 6    Captive giant panda weight                 80–150 kg (176–330 lb)
# 7   Life expectancy in the wild                               20 years
# 8  Life expectancy in captivity   30+ years (oldest recorded 36 years)

# %%
import numpy as np

# %%
archivo_panda.reset_index(drop=True)
# Out:
#                     Body length                     120–180cm (47–71")
# 0               Shoulder height                       54–81cm (21–32")
# 1                    Hip height                       52–77cm (20–30")
# 2                   Chest girth                      70–106cm (28–42")
# 3               Hind leg length                         12–20cm (5–8")
# 4                   Tail length                         10–20cm (4–8")
# 5       Wild giant panda weight                 60–110 kg (132–243 lb)
# 6    Captive giant panda weight                 80–150 kg (176–330 lb)
# 7   Life expectancy in the wild                               20 years
# 8  Life expectancy in captivity   30+ years (oldest recorded 36 years)

# %%
archivo_panda.to_pickle("DATOS/panda.pickle")

# %%
archivo_panda_cambiado = np.swapaxes(archivo_panda,1,0)
archivo_panda_cambiado
# Out:
#                                      0                  1                   2  \
# Body length            Shoulder height         Hip height         Chest girth
#  120–180cm (47–71")   54–81cm (21–32")   52–77cm (20–30")   70–106cm (28–42")
#
#                                    3                4  \
# Body length          Hind leg length      Tail length
#  120–180cm (47–71")   12–20cm (5–8")   10–20cm (4–8")
#
#                                            5                           6  \
# Body length          Wild giant panda weight  Captive giant panda weight
#  120–180cm (47–71")   60–110 kg (132–243 lb)      80–150 kg (176–330 lb)
#
#                                                7  \
# Body length          Life expectancy in the wild
#  120–180cm (47–71")                     20 years
#
#                                                          8
# Body length                   Life expectancy in captivity
#  120–180cm (47–71")   30+ years (oldest recorded 36 years)

# %%
archivo_panda_cambiado.shape
# Out:
# (2, 9)

# %% [markdown]
# Nos parece interesante revisar este ejercisio por esto lo hemos ampliado.
