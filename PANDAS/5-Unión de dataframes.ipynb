# %% [markdown]
# Trabajaremos con tres ficheros diferentes, para acabar con uno general:
# - El csv que creamos en el ejercicio de pair programming Pandas IV.
#
# - El csv llamado attacks_historico donde tenemos información sobre los ataques de tiburón previos al año 1800.
# - El csv llamado attacks_adicional donde tenemos información sobre los ataques de tiburón.

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# 1. Cargad los tres ficheros nombrados anteriormente y los exploramos para familizarizarnos con ellos. Escoged una forma de unirlos.

# %%
attacks_4 = pd.read_csv("PANDAS/DATOS/attacks_con_siglo.csv")

attacks_h = pd.read_csv("PANDAS/DATOS/attacks_historico.csv")

attacks_a = pd.read_csv("PANDAS/DATOS/attacks_adicional.csv")

# %%
print(sorted(attacks_4.columns))
print(sorted(attacks_h.columns))
print(sorted(attacks_a.columns))
# Out:
# ['Unnamed: 0', 'activity', 'age', 'area', 'case_number', 'country', 'href', 'location', 'name', 'sex_', 'siglo', 'species_', 'time', 'type', 'unnamed:_0', 'year']
# ['Activity', 'Age', 'Area', 'Case Number', 'Case Number.1', 'Case Number.2', 'Country', 'Investigator or Source', 'Location', 'Name', 'Sex ', 'Species ', 'Time', 'Type', 'Unnamed: 0', 'Unnamed: 22', 'Unnamed: 23', 'Year', 'href', 'href formula', 'original order', 'pdf']
# ['Case Number', 'Date', 'Fatal (Y/N)', 'Injury', 'Unnamed: 0']

# %%
# Explorando los nombres de las columnas nos damos cuenta de que no están homogeneizados, ya que hay espacios por medio y letras mayúsculas..., y de que la columna 
# "Unnamed: 0" es una columna común en todas, probablemente utilizaremos un merge() para unirlos pero antes queremos unifarmarlo.

# %% [markdown]
# 2. Chequead que los nombres de las columnas ver si se llaman iguales entre dataframes . ¿Están todas en minúsculas? ¿Tienen espacios? En caso de que no sean todas iguales unificad el nombre de las columnas.

# %%
columnas_nuevas_4 = {col : col.lower().replace(" ","_").replace(".","_") for col in attacks_4.columns}
columnas_nuevas_h = {col : col.lower().replace(" ","_").replace(".","_") for col in attacks_h.columns}
columnas_nuevas_a = {col : col.lower().replace(" ","_").replace(".","_") for col in attacks_a.columns}

#print(columnas_nuevas_4)
print(columnas_nuevas_h)
#print(columnas_nuevas_a)
# Out:
# {'Unnamed: 0': 'unnamed:_0', 'Case Number': 'case_number', 'Year': 'year', 'Type': 'type', 'Country': 'country', 'Area': 'area', 'Location': 'location', 'Activity': 'activity', 'Name': 'name', 'Sex ': 'sex_', 'Age': 'age', 'Time': 'time', 'Species ': 'species_', 'Investigator or Source': 'investigator_or_source', 'pdf': 'pdf', 'href formula': 'href_formula', 'href': 'href', 'Case Number.1': 'case_number_1', 'Case Number.2': 'case_number_2', 'original order': 'original_order', 'Unnamed: 22': 'unnamed:_22', 'Unnamed: 23': 'unnamed:_23'}

# %%
attacks_4.rename(columns= columnas_nuevas_4, inplace = True)
attacks_4.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'unnamed:_0', 'year', 'type', 'country',
#        'area', 'location', 'activity', 'name', 'sex_', 'age', 'time',
#        'species_', 'href', 'siglo'],
#       dtype='object')

# %%
attacks_h.rename(columns= columnas_nuevas_h, inplace = True)
attacks_h.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number_1', 'case_number_2', 'original_order', 'unnamed:_22',
#        'unnamed:_23'],
#       dtype='object')

# %%
attacks_a.rename(columns= columnas_nuevas_a, inplace = True)
attacks_a.columns
# Out:
# Index(['unnamed:_0', 'case_number', 'fatal_(y/n)', 'injury', 'date'], dtype='object')

# %% [markdown]
# 3. En este momento nos habremos dado cuenta que el DataFrame que generamos en el pair programming Pandas IV es similar al DataFrame de los datos historicos. Si recordamos, eliminamos algunas columnas en la sesión III que no eran útiles, pero esas columnas están todavía en el histórico. Si no fuera por eso podríamos unir esos dataframes. Realizad los cambios que creais necesarios para que los dataframes sean iguales y luego juntadlos usando el mejor método.

# %%
display(attacks_4.columns, attacks_h.columns)
# Out:
# Index(['unnamed:_0', 'case_number', 'unnamed:_0', 'year', 'type', 'country',
#        'area', 'location', 'activity', 'name', 'sex_', 'age', 'time',
#        'species_', 'href', 'siglo'],
#       dtype='object')
# Index(['unnamed:_0', 'case_number', 'year', 'type', 'country', 'area',
#        'location', 'activity', 'name', 'sex_', 'age', 'time', 'species_',
#        'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number_1', 'case_number_2', 'original_order', 'unnamed:_22',
#        'unnamed:_23'],
#       dtype='object')

# %%
objeto_a = attacks_a[attacks_a["unnamed:_0"]== 0]
objeto_a
# Out:
#    unnamed:_0 case_number fatal_(y/n)  \
# 0           0  2018.06.25           N
#
#                                               injury         date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018

# %%
attacks_4["case_number"].unique()
# Out:
# array(['2018.06.25', '2018.06.03.a', '2018.05.26.b', ..., '1892.03.02',
#        '1880.11.25', '1868.05.13'], dtype=object)

# %%
attacks_4.sample(10)
# Out:
#       unnamed:_0   case_number  unnamed:_0    year        type    country  \
# 157          476    2014.11.13         477  2014.0  Unprovoked        USA
# 51           197    2016.11.28         198  2016.0    Provoked  AUSTRALIA
# 407         1189    2008.10.22        1194  2008.0    Provoked  AUSTRALIA
# 477         1358    2007.07.10        1363  2007.0  Unprovoked    BAHAMAS
# 161          491  2014.10.05.a         492  2014.0  Unprovoked        USA
# 1340        3986    1960.04.14        3998  1960.0     Invalid    BERMUDA
# 500         1406    2007.01.05        1411  2007.0  Unprovoked        USA
# 1148        3208    1975.07.19        3218  1975.0  Unprovoked        USA
# 1223        3569  1966.05.16.b        3580  1966.0     Invalid        USA
# 14            40    2018.02.23          40  2018.0  Unprovoked  AUSTRALIA
#
#                  area                                           location  \
# 157            Hawaii                  Airplane Beach, Lahina, West Maui
# 51           Victoria                                        Queenscliff
# 407   New South Wales                                 Oceanworld, Manley
# 477     Abaco Islands                                Allan-Pensacola Cay
# 161           Florida                   New Smyrna Beach, Volusia County
# 1340         33N, 68W  Royal Canadian Navy CS2F-1 aircraft ditched in...
# 500            Hawaii                                 Majors Bay, Kaua'i
# 1148       California             Point Conception, Santa Barbara County
# 1223          Florida                    Fernandina Beach, Nassau County
# 14    New South Wales                 Little Congwong Beach, La Perouse
#
#                          activity  \
# 157                    Snorkeling
# 51                        Fishing
# 407                  Scuba diving
# 477                  Spearfishing
# 161                       Surfing
# 1340           Floating on a raft
# 500                       Surfing
# 1148    Hookah diving for abalone
# 1223  Spearfishing / Scuba diving
# 14                       Swimming
#
#                                                    name sex_             age  \
# 157                                         Andrew Haas    M              53
# 51                                        Rod McFarlane    M              73
# 407                                         Steve Cloke    M              34
# 477                                        Joanie Regan    F              48
# 161                                     Hilton Mantooth    M              15
# 1340  Crew of aircraft: McGreevy, Beakley, Rosenthal...    M  21, 34,24 & 35
# 500                                           Rich Reed    M              24
# 1148                                       Gary Johnson    M              34
# 1223                                    Steven Oschosky    M              24
# 14                                       Anna Shurapey     F              55
#
#                time                                species_  \
# 157           13h30                             1.5 m shark
# 51            11h00        Broadnose sevengill shark, 1.5 m
# 407           17h20                    Grey nurse shark, 3m
# 477           11h00                         Bull shark, 5'
# 161           11h00                          Blacktip shark
# 1340  09h00 - 09h30                   Questionable incident
# 500           10h15  6' to 8' shark, possibly a tiger shark
# 1148          13h30                   White shark, 5m to 6m
# 1223          14h00                                 Invalid
# 14      19h00, Dusk     Juvenile white shark,  2.7 to 3.2 m
#
#                                                    href      siglo
# 157   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI
# 51    http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI
# 407   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI
# 477   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI
# 161   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI
# 1340  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo XX
# 500   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI
# 1148  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo XX
# 1223  http://sharkattackfile.net/spreadsheets/pdf_di...   siglo XX
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI

# %%
attacks_a
# Out:
#       unnamed:_0 case_number fatal_(y/n)  \
# 0              0  2018.06.25           N
# 1              1  2018.06.18           N
# 2              2  2018.06.09           N
# 3              3  2018.06.08           N
# 4              4  2018.06.04           N
# ...          ...         ...         ...
# 6283        6283     ND.0003           Y
# 6284        6284     ND.0002           Y
# 6285        6285     ND.0001           Y
# 6286        6286           0         NaN
# 6287        6287          xx         NaN
#
#                                                  injury         date
# 0     No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                            Minor injury to left thigh  18-Jun-2018
# 2          Injury to left lower leg from surfboard skeg  09-Jun-2018
# 3                             Minor injury to lower leg  08-Jun-2018
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT  04-Jun-2018
# ...                                                 ...          ...
# 6283                                              FATAL    1900-1905
# 6284                                              FATAL    1883-1889
# 6285  FATAL. "Shark bit him in half, carrying away t...    1845-1853
# 6286                                                NaN          NaN
# 6287                                                NaN          NaN
#
# [6288 rows x 5 columns]

# %%
attacks_h
# Out:
#      unnamed:_0   case_number    year        type             country  \
# 0          6132    1800.00.00  1800.0  Unprovoked          SEYCHELLES
# 1          6133  1797.05.28.R  1797.0  Unprovoked                 NaN
# 2          6134    1792.09.12  1792.0    Provoked             ENGLAND
# 3          6135    1791.00.00  1791.0  Unprovoked           AUSTRALIA
# 4          6136    1788.05.10  1788.0        Boat           AUSTRALIA
# ..          ...           ...     ...         ...                 ...
# 165        6297       ND.0005     0.0  Unprovoked           AUSTRALIA
# 166        6298       ND.0004     0.0  Unprovoked           AUSTRALIA
# 167        6299       ND.0003     0.0  Unprovoked                 USA
# 168        6300       ND.0002     0.0  Unprovoked              PANAMA
# 169        6301       ND.0001     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                   area                             location  \
# 0             St. Anne                                  NaN
# 1                  NaN                                  NaN
# 2                  NaN                  On the Thames River
# 3      New South Wales                         Port Jackson
# 4      New South Wales                        Sydney Harbor
# ..                 ...                                  ...
# 165  Western Australia                          Roebuck Bay
# 166  Western Australia                                  NaN
# 167     North Carolina                       Ocracoke Inlet
# 168                NaN                 Panama Bay 8ºN, 79ºW
# 169   Eastern Province  Below the English fort, Trincomalee
#
#                             activity                              name sex_  \
# 0    a corsair's boat was overturned                               NaN    F
# 1                  Dropped overboard                             child  NaN
# 2                            Fishing                              male    M
# 3                                NaN  female, an Australian aboriginal    F
# 4                            Fishing                              boat  NaN
# ..                               ...                               ...  ...
# 165                           Diving                              male    M
# 166                     Pearl diving                             Ahmun    M
# 167                         Swimming             Coast Guard personnel    M
# 168                              NaN                   Jules Patterson    M
# 169                         Swimming                              male    M
#
#      ... species_                             investigator_or_source  \
# 0    ...      NaN                                 V. C. Harvey-Brain
# 1    ...      NaN                             The Observer 5/28/1797
# 2    ...      NaN                    The Waterford Herald, 9/15/1792
# 3    ...      NaN                 G.P. Whitley;  D. Baldridge, p.162
# 4    ...      NaN  G.P. Whitley citing J. Cobley, Sydney Cove, p....
# ..   ...      ...                                                ...
# 165  ...      NaN                   H. Taunton; N. Bartlett,  p. 234
# 166  ...      NaN              H. Taunton; N. Bartlett,  pp. 233-234
# 167  ...      NaN               F. Schwartz, p.23; C. Creswell, GSAF
# 168  ...      NaN                                The Sun, 10/20/1938
# 169  ...      NaN                                         S.W. Baker
#
#                                  pdf  \
# 0        1800.00.00-Corsair-boat.pdf
# 1        1797.05.28.R-Cloverdale.pdf
# 2              1792.09.12-Thames.pdf
# 3    1791.00.00-aboriginal woman.pdf
# 4                  1788.05.10-Sydney
# ..                               ...
# 165           ND-0005-RoebuckBay.pdf
# 166                ND-0004-Ahmun.pdf
# 167   ND-0003-Ocracoke_1900-1905.pdf
# 168       ND-0002-JulesPatterson.pdf
# 169               ND-0001-Ceylon.pdf
#
#                                           href_formula  \
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...
# ..                                                 ...
# 165  http://sharkattackfile.net/spreadsheets/pdf_di...
# 166  http://sharkattackfile.net/spreadsheets/pdf_di...
# 167  http://sharkattackfile.net/spreadsheets/pdf_di...
# 168  http://sharkattackfile.net/spreadsheets/pdf_di...
# 169  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href case_number_1  \
# 0    http://sharkattackfile.net/spreadsheets/pdf_di...    1800.00.00
# 1    http://sharkattackfile.net/spreadsheets/pdf_di...  1797.05.28.R
# 2    http://sharkattackfile.net/spreadsheets/pdf_di...    1792.09.12
# 3    http://sharkattackfile.net/spreadsheets/pdf_di...    1791.00.00
# 4    http://sharkattackfile.net/spreadsheets/pdf_di...    1788.05.10
# ..                                                 ...           ...
# 165  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 166  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 167  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 168  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 169  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#     case_number_2 original_order unnamed:_22  unnamed:_23
# 0      1800.00.00          171.0         NaN          NaN
# 1    1797.05.28.R          170.0         NaN          NaN
# 2      1792.09.12          169.0         NaN          NaN
# 3      1791.00.00          168.0         NaN          NaN
# 4      1788.05.10          167.0         NaN          NaN
# ..            ...            ...         ...          ...
# 165       ND.0005            6.0         NaN          NaN
# 166       ND.0004            5.0         NaN          NaN
# 167       ND.0003            4.0         NaN          NaN
# 168       ND.0002            3.0         NaN          NaN
# 169       ND.0001            2.0         NaN          NaN
#
# [170 rows x 22 columns]

# %% [markdown]
# 4. Es el momento de unir la información de todos los ataques de tiburón que acabamos de crear con el DataFrame de información adicional. Debatid que método es el más correcto para unir toda esta información y ejecutadlo.
# - NOTA Cuando hagáis la unión considerad que la información que más nos interesa es la del DataFrame que creamos en el apartado anterior, lo cual determinará el tipo de unión.

# %% [markdown]
# 5. Guardad el dataframe nuevo en un csv que usaremos mañana en la clase de pair programming.
