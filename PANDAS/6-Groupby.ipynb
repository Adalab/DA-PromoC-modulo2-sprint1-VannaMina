# %%
# importamos las librerías que necesitamos

import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/admin/Documents/DA-PromoC-modulo2-sprint1-VannaMina/PANDAS'

# %%
#vamos a trabajar con el csv creado en el ejercicio de pair programming anterior.

fichero = pd.read_csv("DATOS/attacks_pandas5.csv")

# %% [markdown]
# 1. ¿Cuántos ataques hubo por país? Devuelve un DataFrame.
#
# 📌 NOTA Ordena los resultados de mayor a menor. Esto todavía no lo hemos visto, pero un DataFrame lo podemos ordenar con `.sort_values()`.

# %%
fichero.head(2)
# Out:
#     case_number  unnamed:_0    year        type country        area  \
# 0    2018.06.25           0  2018.0     Boating     USA  California
# 1  2018.06.03.a           6  2018.0  Unprovoked  BRAZIL  Pernambuco
#
#                       location  activity                    name sex_ age  \
# 0  Oceanside, San Diego County  Paddling             Julie Wolfe    F  57
# 1        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
#
#              time     species_  \
# 0           18h00  White shark
# 1  Late afternoon  Tiger shark
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI           Y
#
#                                               injury         date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                                              FATAL  03-Jun-2018

# %%
ataques = fichero.groupby("country").count()
ataques.head()
# Out:
#                 case_number  unnamed:_0  year  type  area  location  activity  \
# country
# AMERICAN SAMOA            2           2     2     2     2         2         2
# ARGENTINA                 1           1     1     1     1         1         1
# ASIA?                     1           1     1     1     0         0         1
# AUSTRALIA               343         343   343   343   338       335       338
# BAHAMAS                  29          29    29    29    29        28        28
#
#                 name  sex_  age  time  species_  href  siglo  fatal_(y/n)  \
# country
# AMERICAN SAMOA     2     2    2     2         2     2      2            0
# ARGENTINA          1     1    1     1         1     1      1            0
# ASIA?              1     1    0     0         0     1      0            0
# AUSTRALIA        343   342  325   324       330   343    324           46
# BAHAMAS           29    29   26    26        29    29     26            2
#
#                 injury  date
# ...

# %%
ataques_ordenados = ataques.sort_values(by = "case_number" ,axis = 0, ascending = False)
ataques_ordenados.head()
# Out:
#               case_number  unnamed:_0  year  type  area  location  activity  \
# country
# USA                   741         741   741   741   740       739       739
# AUSTRALIA             343         343   343   343   338       335       338
# SOUTH AFRICA          234         234   234   234   234       234       234
# BAHAMAS                29          29    29    29    29        28        28
# NEW ZEALAND            21          21    21    21    21        21        20
#
#               name  sex_  age  time  species_  href  siglo  fatal_(y/n)  \
# country
# USA            741   741  722   720       726   741    719           81
# AUSTRALIA      343   342  325   324       330   343    324           46
# SOUTH AFRICA   234   234  226   226       226   234    226            9
# BAHAMAS         29    29   26    26        29    29     26            2
# NEW ZEALAND     21    21   20    20        20    21     20            1
#
#               injury  date
# country
# ...

# %% [markdown]
# 2. ¿Cuántos ataques ha habido por año? Devuelve un DataFrame. De nuevo ordena los resultados de mayor a menor. `.sort_values()`

# %%
ataques_años = (fichero.groupby("year").count()).sort_values(by = "year" ,axis = 0,  ascending = False)
ataques_años.head()
# Out:
#         case_number  unnamed:_0  type  country  area  location  activity  \
# year
# 2018.0           17          17    17       17    17        17        17
# 2017.0           30          30    30       30    30        30        30
# 2016.0           37          37    37       37    37        37        37
# 2015.0           68          68    68       68    68        68        68
# 2014.0           35          35    35       35    35        35        35
#
#         name  sex_  age  time  species_  href  siglo  fatal_(y/n)  injury  \
# year
# 2018.0    17    17   17    17        17    17     17           17      17
# 2017.0    30    30   30    30        30    30     30           25      30
# 2016.0    37    37   37    37        37    37     37           35      37
# 2015.0    68    68   68    68        68    68     68           63      68
# 2014.0    35    35   35    35        35    35     35           19      19
#
#         date
# year
# 2018.0    17
# 2017.0    30
# 2016.0    37
# ...

# %% [markdown]
# 3. ¿Cuántos ataques hubo por año y sexo? Devolved un DataFrame solo del año 2000 en adelante.

# %%
ataques_a_s = fichero.groupby(["year","sex_"])["case_number"].count().reset_index()
ataques_a_s
# Out:
#        year sex_  case_number
# 0       0.0    F           13
# 1       0.0    M          104
# 2       5.0    M            1
# 3      77.0    M            1
# 4     500.0    M            1
# ..      ...  ...          ...
# 191  2016.0    M           30
# 192  2017.0    F            9
# 193  2017.0    M           21
# 194  2018.0    F            2
# 195  2018.0    M           15
#
# [196 rows x 3 columns]

# %% [markdown]
# 4. Primero extraed solo las filas que correspondan a USA, AUSTRALIA y SOUTH AFRICA.
#
#     ¿Cuántos de los ataques fueron letales por sexo?
#     Devuelve un DataFrame.

# %%
ataques_uas = fichero[(fichero["country"] == "USA") | (fichero["country"] == "AUSTRALIA") | (fichero["country"] == "SOUTH AFRICA")]
ataques_uas.head(3)
# Out:
#     case_number  unnamed:_0    year        type    country        area  \
# 0    2018.06.25           0  2018.0     Boating        USA  California
# 2  2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
#
#                        location        activity         name sex_ age  \
# 0   Oceanside, San Diego County        Paddling  Julie Wolfe    F  57
# 2  Cocoa Beach, Brevard  County         Walking    Cody High    M  15
# 3               Cairns Aquarium  Feeding sharks         male    M  32
#
#       time         species_  \
# 0    18h00      White shark
# 2    17h00   Bull shark, 6'
# 3  Morning  Grey reef shark
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI           N
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI           N
# ...

# %%
#para comprobar el resultado de los ataques que han sido fatales hemos averiguado la columna fatal_(y/n)

ataques_uas["fatal_(y/n)"].value_counts()
# Out:
# N    128
# Y      8
# Name: fatal_(y/n), dtype: int64

# %%
ataques_fatales = ataques_uas[ataques_uas["fatal_(y/n)"]=="Y"].groupby("sex_")["case_number"].count().reset_index()
ataques_fatales

#Hemos entendido que la pregunta es: numero de ataques fatales por sexo.
# Out:
#   sex_  case_number
# 0    F            2
# 1    M            6

# %% [markdown]
# 5. Usando el DataFrame creado en el ejercicio anterior.
#
#     ¿En qué país hubo más ataques?

# %%
#En el Dataframe anterior hay solamente los ataques por cada "sexo", por lo cual tendremos que hacer otro aprovechando el codigo del anterior

pais_fatal = ataques_uas[ataques_uas["fatal_(y/n)"]=="Y"].groupby("country")["case_number"].count().reset_index()
pais_fatal
# Out:
#      country  case_number
# 0  AUSTRALIA            8

# %% [markdown]
# 6. ¿Qué y cuántos tipos de ataques hubo por país?

# %%
tipologia_ataque = fichero.groupby("country")["type"].count()
tipologia_ataque
# Out:
# country
# AMERICAN SAMOA      2
# ARGENTINA           1
# ASIA?               1
# AUSTRALIA         343
# BAHAMAS            29
#                  ...
# URUGUAY             2
# USA               741
# VANUATU             4
# VENEZUELA           4
# VIETNAM             5
# Name: type, Length: 95, dtype: int64

# %%
b = fichero.groupby("type")["country"].count()
b
# Out:
# type
# Boat               4
# Boating           17
# Invalid           92
# Provoked         114
# Sea Disaster      11
# Unprovoked      1424
# Name: country, dtype: int64

# %%
tipologia_ataque = fichero.groupby("country","type").count()
tipologia_ataque
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 'type'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/66/3gn2x5sj3tlfxjp4wp1zg9n00000gn/T/ipykernel_12673/2504038273.py in <module>
# ----> 1 tipologia_ataque = fichero.groupby("country","type").count()
#       2 tipologia_ataque
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8395         if level is None and by is None:
# ...

# %%
f_mean_std = df.groupby(["gender", "vehicle_size"])['number_of_policies'].agg(["mean", 'std'])
df_mean_std.reset_index(inplace = True)
df_mean_std
